# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
answers = pd.read_csv("C:/Users/GORDON OUMA GOGAH/Desktop/python programming/data/Answers.csv",encoding='ISO-8859-1')
question = pd.read_csv("C:/Users/GORDON OUMA GOGAH/Desktop/python programming/data/Questions.csv",encoding='ISO-8859-1')
tags = pd.read_csv("C:/Users/GORDON OUMA GOGAH/Desktop/python programming/data/Tags.csv",encoding='ISO-8859-1')

# %%
answers
# Out:
#                Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0              92         61.0  2008-08-01T14:45:37Z        90     13
# 1             124         26.0  2008-08-01T16:09:47Z        80     12
# 2             199         50.0  2008-08-01T19:36:46Z       180      1
# 3             269         91.0  2008-08-01T23:49:57Z       260      4
# 4             307         49.0  2008-08-02T01:49:46Z       260     28
# ...           ...          ...                   ...       ...    ...
# 2014511  40143247     333403.0  2016-10-19T23:42:35Z  40143190      0
# 2014512  40143322     642706.0  2016-10-19T23:50:35Z  40137110      1
# 2014513  40143336    2239781.0  2016-10-19T23:52:08Z  40141860      0
# 2014514  40143349    6934347.0  2016-10-19T23:54:02Z  40077010      0
# 2014515  40143389    4464432.0  2016-10-19T23:58:58Z  40142910      0
#
#                                                       Body
# 0        <p><a href="http://svnbook.red-bean.com/">Vers...
# ...

# %%
question
# Out:
#                Id  OwnerUserId          CreationDate            ClosedDate  \
# 0              80         26.0  2008-08-01T13:57:07Z                   NaN
# 1              90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z
# 2             120         83.0  2008-08-01T15:50:08Z                   NaN
# 3             180    2089740.0  2008-08-01T18:42:19Z                   NaN
# 4             260         91.0  2008-08-01T23:22:08Z                   NaN
# ...           ...          ...                   ...                   ...
# 1264211  40143210    5610777.0  2016-10-19T23:38:01Z                   NaN
# 1264212  40143300    3791161.0  2016-10-19T23:48:09Z                   NaN
# 1264213  40143340    7028647.0  2016-10-19T23:52:50Z                   NaN
# 1264214  40143360     871677.0  2016-10-19T23:55:24Z                   NaN
# 1264215  40143380    6823982.0  2016-10-19T23:57:31Z                   NaN
#
#          Score                                              Title  \
# ...

# %%
tags
# Out:
#                Id             Tag
# 0              80            flex
# 1              80  actionscript-3
# 2              80             air
# 3              90             svn
# 4              90     tortoisesvn
# ...           ...             ...
# 3750989  40143360      javascript
# 3750990  40143360          vue.js
# 3750991  40143380             npm
# 3750992  40143380           mocha
# 3750993  40143380           babel
#
# [3750994 rows x 2 columns]

# %%
df = (pd.read_csv("C:/Users/GORDON OUMA GOGAH/Desktop/python programming/data/Questions.csv",nrows=1_000_000,encoding='ISO-8859-1',usecols=['Title','Id']))
titles = [_ for _ in df['Title']]

# %%
import random
random.choices(titles,k=20)
# Out:
# ['How to offset latest 3 posts in Genesis - Eleven40 pro Theme',
#  'How to stop text at screen borders?',
#  'Android Intent launch from browser',
#  'Set default content for target div',
#  'HttpContext.Current.User.Identity.Name returns null when website folder moved',
#  'SQL query for sorting leaderboard',
#  'Ignore invalid self-signed ssl certificate in node.js with https.request?',
#  'Flex - Disabling the transparent background overlay on a popup',
#  'Correct pattern for a VIM autocommand?',
#  'Build PHP without a C++ compiler',
#  'CKEDITOR: how to I convert ALL html entities',
#  'Converting Winform ContextMenu to Wpf ContextMenu',
#  'Android buttons not displaying on top of SurfaceView',
#  'SQL - How to handle two conditions without using AND?',
#  'Can jQuery or AJAX listen for a variable passed over from another page?',
#  'Portion of iPad simulator screen responsive to swipes, but not button clicks',
#  'How to evaluate Enum in an If statement?',
# ...
