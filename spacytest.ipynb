# %%
import spacy

# %%
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
text = nlp('coding is good and healthy for mind joging')
for sent in text:
    print(sent)
# Out:
# coding
# is
# good
# and
# healthy
# for
# mind
# joging

# %%
print(text[:2])
print(text[:7])
# Out:
# coding is
# coding is good and healthy for mind

# %%
doc = nlp('The brown fox has jumped over the lazy dog. Mr peanut wears a top hat')
tags = set()

for word in doc:
    tags.add(word.tag_)
    print((word.text,word.pos_,word.tag_))

print()
for tag in tags:
    print(tag, spacy.explain(tag))
# Out:
# ('The', 'DET', 'DT')
# ('brown', 'ADJ', 'JJ')
# ('fox', 'NOUN', 'NN')
# ('has', 'AUX', 'VBZ')
# ('jumped', 'VERB', 'VBN')
# ('over', 'ADP', 'IN')
# ('the', 'DET', 'DT')
# ('lazy', 'ADJ', 'JJ')
# ('dog', 'NOUN', 'NN')
# ('.', 'PUNCT', '.')
# ('Mr', 'PROPN', 'NNP')
# ('peanut', 'NOUN', 'NN')
# ('wears', 'VERB', 'VBZ')
# ('a', 'DET', 'DT')
# ('top', 'ADJ', 'JJ')
# ('hat', 'NOUN', 'NN')
#
# VBZ verb, 3rd person singular present
# NN noun, singular or mass
# VBN verb, past participle
# . punctuation mark, sentence closer
# NNP noun, proper singular
# IN conjunction, subordinating or preposition
# JJ adjective
# DT determiner

# %%
import wikipedia

def pages_to_sentences(*pages):
    sentenses = []
    for page in pages:
        p = wikipedia.page(page)
        doc = nlp(p.content)
        sentenses += [sent.text for sent in doc.sents]
    return sentenses
animal_sents = pages_to_sentences('Reticulated python','Ball Python')
program_sents = pages_to_sentences('Python (programming language)')
documents = animal_sents + program_sents

print(animal_sents[:5])
print()
print(program_sents[:5])
# Out:
# ['The reticulated python (Malayopython reticulatus) is a snake species in the family Pythonidae native to South and Southeast Asia.', "It is the world's longest snake and listed as least concern on the IUCN Red List because of its wide distribution.", 'In several range countries, it is hunted for its skin, for use in traditional medicine, and for sale as a pet.', 'It is an excellent swimmer, has been reported far out at sea and has colonized many small islands within its range.\n', 'It is among the three heaviest snakes.']
#
# ['Python is an interpreted, high-level, general-purpose programming language.', "Created by Guido van Rossum and first released in 1991, Python's design philosophy emphasizes code readability with its notable use of significant whitespace.", 'Its language constructs and object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects.', 'Python is dynamically typed and garbage-collected.', 'It supports multiple programming paradigms, including structured (particularly, procedural), object-oriented, and functional programming.']

# %%
type(documents)
# Out:
# list

# %%
documents[0]
# Out:
# 'The reticulated python (Malayopython reticulatus) is a snake species in the family Pythonidae native to South and Southeast Asia.'

# %%
from sklearn.feature_extraction.text import CountVectorizer

bag_of_words = CountVectorizer()
bag_of_words.fit(documents)
word_counts = bag_of_words.transform(documents)

print(word_counts)
word_counts
# Out:
#   (0, 228)	1
#   (0, 279)	1
#   (0, 987)	1
#   (0, 1279)	1
#   (0, 1371)	1
#   (0, 1546)	1
#   (0, 1699)	1
#   (0, 2028)	1
#   (0, 2031)	1
#   (0, 2151)	1
#   (0, 2153)	1
#   (0, 2350)	1
#   (0, 2372)	1
#   (0, 2373)	1
#   (0, 2383)	1
#   (0, 2555)	2
#   (0, 2592)	1
#   (1, 228)	1
#   (1, 278)	1
#   (1, 344)	1
#   (1, 600)	1
#   (1, 797)	1
#   (1, 1371)	1
#   (1, 1376)	1
#   (1, 1388)	1
#   :	:
#   (847, 1372)	1
#   (848, 51)	1
#   (848, 1571)	1
#   (848, 2485)	1
#   (849, 1279)	1
#   (849, 1986)	1
#   (849, 2028)	1
#   (850, 71)	1
#   (850, 845)	1
#   (851, 162)	1
#   (851, 1979)	1
#   (851, 2751)	1
#   (852, 77)	1
#   (852, 114)	1
#   (852, 130)	1
#   (852, 1372)	1
#   (854, 975)	1
#   (854, 1492)	1
#   (855, 293)	1
#   (855, 689)	1
#   (855, 1440)	1
#   (855, 1781)	1
#   (855, 1986)	1
#   (855, 2028)	1
#   (855, 2741)	1
# <856x2828 sparse matrix of type '<class 'numpy.int64'>'
# 	with 9166 stored elements in Compressed Sparse Row format>

# %%
bag_of_words.get_feature_names()
# Out:
# ['000',
#  '10',
#  '11',
#  '111',
#  '116',
#  '12',
#  '125',
#  '13',
#  '130',
#  '14',
#  '15',
#  '1500',
#  '158',
#  '15806',
#  '16',
#  '165',
#  '17',
#  '18',
#  '1801',
#  '1802',
#  '1803',
#  '182',
#  '1830',
#  '1849',
#  '19',
#  '1910s',
#  '1927',
#  '1932',
#  '1950s',
#  '1956',
#  '1960s',
#  '1963',
#  '1972',
#  '1978',
#  '1980',
#  '1980s',
#  '1989',
#  '1991',
#  '1992',
#  '1993',
#  '1995',
#  '20',
#  '200',
#  '2000',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2015',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '20th',
#  '21',
#  '22',
#  '23',
#  '2415',
#  '25',
#  '26',
#  '28',
#  '29',
#  '2d',
#  '2nd',
#  '2to3',
#  '30',
#  '300',
#  '31',
#  '32',
#  '321',
#  '333',
#  '35',
#  '350',
#  '356',
#  '36',
#  '3d',
#  '3ds',
#  '3rd',
#  '40',
#  '400',
#  '42',
#  '43',
#  '4302',
#  '44',
#  '45',
#  '47',
#  '48',
#  '4d',
#  '50',
#  '500',
#  '51',
#  '521',
#  '53',
#  '54',
#  '55',
#  '561',
#  '59',
#  '59059',
#  '596',
#  '5th',
#  '60',
#  '600',
#  '604259',
#  '61',
#  '635',
#  '67',
#  '68056',
#  '69',
#  '70',
#  '72',
#  '72596',
#  '74',
#  '75',
#  '78',
#  '79',
#  '80',
#  '800',
#  '82',
#  '85',
#  '88',
#  '90',
#  '95',
#  '978',
#  '__',
#  '__future',
#  'abandoned',
#  'abaqus',
#  'abc',
#  'abilities',
#  'ability',
#  'able',
#  'about',
#  'above',
#  'academic',
#  'accept',
#  'acceptance',
#  'accepted',
#  'access',
#  'accessed',
#  'accessible',
#  'accidentally',
#  'according',
#  'accurately',
#  'achieved',
#  'acknowledgements',
#  'acquiring',
#  'acquisition',
#  'across',
#  'active',
#  'actually',
#  'adapting',
#  'add',
#  'added',
#  'adding',
#  'addison',
#  'addition',
#  'additional',
#  'address',
#  'adds',
#  'adept',
#  'adjacent',
#  'administration',
#  'admirers',
#  'adopted',
#  'adoption',
#  'adult',
#  'adults',
#  'advantage',
#  'aestivate',
#  'aeta',
#  'africa',
#  'african',
#  'after',
#  'afterwards',
#  'age',
#  'aggressive',
#  'agitated',
#  'agree',
#  'ai',
#  'aid',
#  'aim',
#  'ajax',
#  'akbar',
#  'al',
#  'albino',
#  'alcohol',
#  'alex',
#  'algebra',
#  'alias',
#  'all',
#  'allanspetcenter',
#  'allen',
#  'allocated',
#  'allocating',
#  'allow',
#  'allowing',
#  'allows',
#  'almost',
#  'along',
#  'alpha',
#  'alpha1',
#  'also',
#  'altered',
#  'altering',
#  'although',
#  'always',
#  'am',
#  'amazon',
#  'ambush',
#  'american',
#  'amid',
#  'amigaos',
#  'amoeba',
#  'among',
#  'amzi',
#  'an',
#  'anaconda',
#  'analogous',
#  'analysis',
#  'analytics',
#  'and',
#  'anesthesia',
#  'anesthetized',
#  'animal',
#  'animals',
#  'animation',
#  'announced',
#  'anonymous',
#  'another',
#  'answers',
#  'anterior',
#  'any',
#  'anything',
#  'apache',
#  'aphorisms',
#  'api',
#  'app',
#  'apparent',
#  'apparently',
#  'appear',
#  'appeared',
#  'apple',
#  'applications',
#  'apply',
#  'approach',
#  'approaches',
#  'apress',
#  'april',
#  'aquarium',
#  'arbitrary',
#  'arboreal',
#  'arcgis',
#  'archipelago',
#  'architecture',
#  'archived',
#  'are',
#  'area',
#  'areas',
#  'argument',
#  'arithmetic',
#  'arnold',
#  'around',
#  'arranged',
#  'array',
#  'arrays',
#  'arriving',
#  'article',
#  'articles',
#  'artificial',
#  'artificially',
#  'as',
#  'asia',
#  'asiatic',
#  'aspect',
#  'aspects',
#  'asphyxiation',
#  'assert',
#  'assigned',
#  'assigning',
#  'assignment',
#  'assignments',
#  'assigns',
#  'associate',
#  'associated',
#  'astropy',
#  'at',
#  'attached',
#  'attaches',
#  'attack',
#  'attacks',
#  'attempt',
#  'attempting',
#  'attention',
#  'attractive',
#  'august',
#  'auliya',
#  'australia',
#  'australian',
#  'australo',
#  'authenticated',
#  'author',
#  'authors',
#  'auto',
#  'automates',
#  'automation',
#  'available',
#  'average',
#  'avoid',
#  'avoiding',
#  'away',
#  'axanthic',
#  'back',
#  'backgrounds',
#  'backported',
#  'backslash',
#  'backslashes',
#  'backward',
#  'balance',
#  'bali',
#  'balikpapan',
#  'ball',
#  'bangkok',
#  'bangladesh',
#  'banned',
#  'bar',
#  'barry',
#  'basal',
#  'based',
#  'basilan',
#  'basis',
#  'batteries',
#  'be',
#  'bear',
#  'beautiful',
#  'beauty',
#  'became',
#  'because',
#  'bedroom',
#  'been',
#  'before',
#  'began',
#  'begin',
#  'beginner',
#  'behalf',
#  'behavior',
#  'behaviors',
#  'behaviour',
#  'behaviours',
#  'behind',
#  'being',
#  'belly',
#  'belongings',
#  'benchmarked',
#  'benchmarks',
#  'benefit',
#  'benevolent',
#  'benin',
#  'best',
#  'bestowed',
#  'beta',
#  'better',
#  'between',
#  'bind',
#  'binding',
#  'binds',
#  'binturong',
#  'biopython',
#  'bird',
#  'birds',
#  'bissau',
#  'bite',
#  'black',
#  'blah',
#  'blender',
#  'block',
#  'blocks',
#  'blotches',
#  'blue',
#  'boa',
#  'board',
#  'body',
#  'bohol',
#  'boo',
#  'book',
#  'boolean',
#  'borneo',
#  'borrowed',
#  'both',
#  'bottle',
#  'bound',
#  'boy',
#  'brackets',
#  'break',
#  'breaking',
#  'bred',
#  'breed',
#  'breeders',
#  'breeding',
#  'brett',
#  'bring',
#  'brings',
#  'british',
#  'broghammer',
#  'broghammerus',
#  'brongersma',
#  'brother',
#  'brown',
#  'browser',
#  'buck',
#  'bug',
#  'bugfix',
#  'bugfixes',
#  'bugs',
#  'build',
#  'buildbot',
#  'built',
#  'bulge',
#  'burma',
#  'burmese',
#  'burrows',
#  'bushes',
#  'busy',
#  'but',
#  'by',
#  'bytecode',
#  'c89',
#  'c99',
#  'cadence',
#  'calculate',
#  'calculus',
#  'call',
#  'called',
#  'calling',
#  'calls',
#  'cambodia',
#  'came',
#  'cameroon',
#  'can',
#  'candidates',
#  'cannon',
#  'cannot',
#  'canopy',
#  'capabilities',
#  'capable',
#  'capella',
#  'captive',
#  'captivity',
#  'capture',
#  'capturing',
#  'cardboard',
#  'care',
#  'carnegie',
#  'carol',
#  'carried',
#  'carry',
#  'case',
#  'cases',
#  'catch',
#  'cats',
#  'caught',
#  'cause',
#  'causes',
#  'cdc',
#  'cebu',
#  'celsius',
#  'cenchris',
#  'centers',
#  'central',
#  'centrum',
#  'century',
#  'cern',
#  'certain',
#  'chad',
#  'chained',
#  'chance',
#  'chances',
#  'change',
#  'changed',
#  'character',
#  'characters',
#  'check',
#  'checked',
#  'checker',
#  'checking',
#  'chicken',
#  'chickens',
#  'chief',
#  'child',
#  'choice',
#  'christian',
#  'chronicle',
#  'cinema',
#  'circuitpython',
#  'cited',
#  'city',
#  'civet',
#  'clade',
#  'cladistics',
#  'claim',
#  'claimed',
#  'claims',
#  'clarity',
#  'class',
#  'classes',
#  'classic',
#  'clauses',
#  'clean',
#  'clear',
#  'clever',
#  'client',
#  'climbing',
#  'cloaca',
#  'close',
#  'closely',
#  'closing',
#  'clutch',
#  'cluttered',
#  'cm',
#  'coast',
#  'cobra',
#  'coconut',
#  'code',
#  'coding',
#  'coffeescript',
#  'coffin',
#  'coghlan',
#  'cognitive',
#  'coiled',
#  'coiling',
#  'coils',
#  'colleagues',
#  'collected',
#  'collecting',
#  'collection',
#  'collector',
#  'colonized',
#  'color',
#  'colors',
#  'colossus',
#  'colour',
#  'colouration',
#  'colours',
#  'com',
#  'combination',
#  'combinatorial',
#  'combinatorics',
#  'combined',
#  'combining',
#  'come',
#  'comedy',
#  'comes',
#  'comfortable',
#  'command',
#  'commented',
#  'commercial',
#  'commitment',
#  'common',
#  'commonly',
#  'communications',
#  'communities',
#  'community',
#  'compact',
#  'compare',
#  'compared',
#  'compares',
#  'comparison',
#  'comparisons',
#  'compatible',
#  'compensate',
#  'competitors',
#  'compile',
#  'compiled',
#  'compiler',
#  'compilers',
#  'compiles',
#  'completely',
#  'completion',
#  'complex',
#  'compliant',
#  'complicated',
#  'compliment',
#  'component',
#  'compositor',
#  'comprehension',
#  'comprehensions',
#  'comprehensive',
#  'computer',
#  'computers',
#  'computerworld',
#  'computing',
#  'concatenate',
#  'conceived',
#  'concern',
#  'concluded',
#  'concurrent',
#  'condition',
#  'conditional',
#  'conditionally',
#  'conditions',
#  'conducted',
#  'conference',
#  'confirmed',
#  'conforming',
#  'conforms',
#  'confusion',
#  'connected',
#  'connecting',
#  'cons',
#  'consequently',
#  'conservation',
#  'consider',
#  'considerable',
#  'considered',
#  'considering',
#  'consist',
#  'consistency',
#  'consistent',
#  'consistently',
#  'consists',
#  'constraints',
#  'constrict',
#  'constriction',
#  'constrictor',
#  'constrictors',
#  'constructed',
#  'constructs',
#  'consumption',
#  'contain',
#  'containers',
#  'containing',
#  'contains',
#  'contents',
#  'context',
#  'contexts',
#  'continuations',
#  'continue',
#  'continues',
#  'continuous',
#  'continuously',
#  'contract',
#  'contraction',
#  'contrary',
#  'contrast',
#  'control',
#  'controversy',
#  'conventional',
#  'conventions',
#  'cool',
#  'copied',
#  'copulation',
#  'copy',
#  'core',
#  'cores',
#  'cornell',
#  'coroutine',
#  'coroutines',
#  'corresponding',
#  'corresponds',
#  'cosmetic',
#  'cost',
#  'could',
#  'council',
#  'counting',
#  'countries',
#  'counts',
#  'couple',
#  'course',
#  'covered',
#  'covers',
#  'cpython',
#  'cream',
#  'create',
#  'created',
#  'creating',
#  'creator',
#  'critical',
#  'criticized',
#  'cross',
#  'crossing',
#  'culture',
#  'curl',
#  'curlie',
#  'curling',
#  'curly',
#  'current',
#  'currently',
#  'cut',
#  'cwi',
#  'cycle',
#  'cycles',
#  'cython',
#  'cytochrome',
#  'cz',
#  'dalegibbonsi',
#  'danger',
#  'dark',
#  'data',
#  'database',
#  'databases',
#  'date',
#  'daudin',
#  'day',
#  'days',
#  'dead',
#  'deal',
#  'death',
#  'deaths',
#  'debris',
#  'debugger',
#  'debugging',
#  'december',
#  'decided',
#  'decimal',
#  'decimals',
#  'decision',
#  'decisions',
#  'declared',
#  'decrease',
#  'deep',
#  'def',
#  'default',
#  'defects',
#  'defense',
#  'define',
#  'defined',
#  'defines',
#  'definition',
#  'degrees',
#  'delayed',
#  'delimit',
#  'delimited',
#  'denoted',
#  'depends',
#  'deposited',
#  'derived',
#  'describe',
#  'described',
#  'describing',
#  'description',
#  'design',
#  'designated',
#  'designed',
#  'designer',
#  'desire',
#  'desktop',
#  'despite',
#  'destroyed',
#  'details',
#  'detecting',
#  'determined',
#  'determining',
#  'dev',
#  'develop',
#  'developed',
#  'developer',
#  'developers',
#  'developing',
#  'development',
#  'develops',
#  'device',
#  'diamond',
#  'dictator',
#  'dictionaries',
#  'dictionary',
#  'died',
#  'diet',
#  'differed',
#  'difference',
#  'different',
#  'differently',
#  'differs',
#  'difficult',
#  'difficulty',
#  'digest',
#  'direct',
#  'directly',
#  'directs',
#  'disappear',
#  'disarticulated',
#  'discontinued',
#  'discovered',
#  'discussed',
#  'display',
#  'disposition',
#  'disruptive',
#  'distinct',
#  'distinction',
#  'distinguished',
#  'distributed',
#  'distribution',
#  'distributions',
#  'dive',
#  'division',
#  'divisions',
#  'django',
#  'dna',
#  'do',
#  'document',
#  'documentation',
#  'documented',
#  'documenting',
#  'documents',
#  'does',
#  'doesn',
#  'dogs',
#  'domain',
#  'domestic',
#  'dorsal',
#  'double',
#  'down',
#  'downey',
#  'draws',
#  'drill',
#  'dropbox',
#  'dropped',
#  'duck',
#  'due',
#  'duplicating',
#  'during',
#  'dwarf',
#  'dwarfs',
#  'dynamic',
#  'dynamically',
#  'each',
#  'earlier',
#  'earliest',
#  'early',
#  'earth',
#  'easiest',
#  'easily',
#  'east',
#  'easy',
#  'eat',
#  'eaten',
#  'eating',
#  'ecmascript',
#  'ecology',
#  'ed',
#  'edward',
#  'effective',
#  'effectively',
#  'effects',
#  'efforts',
#  'eggs',
#  'eggsclass',
#  'eight',
#  'either',
#  'elected',
#  'element',
#  'elements',
#  'eleven',
#  'elif',
#  'eliminated',
#  'else',
#  'embedded',
#  'embraces',
#  'emitted',
#  'emphasis',
#  'emphasizes',
#  'emphasizing',
#  'empirical',
#  'empty',
#  'emulated',
#  'enables',
#  'enabling',
#  'encloses',
#  'enclosure',
#  'enclosures',
#  'encouraged',
#  'end',
#  'ends',
#  'enemies',
#  'enforced',
#  'engine',
#  'english',
#  'enhancement',
#  'enjoyed',
#  'enough',
#  'enrichment',
#  'ensure',
#  'ensures',
#  'entering',
#  'enters',
#  'entire',
#  'entirely',
#  'entities',
#  'environment',
#  'environments',
#  'enygrus',
#  'epydoc',
#  'equal',
#  'equality',
#  'equals',
#  'equation',
#  'erected',
#  'erlang',
#  'erroneous',
#  'error',
#  'escape',
#  'escaped',
#  'escaping',
#  'especially',
#  'espoused',
#  'esri',
#  'establishing',
#  'estimated',
#  'estimations',
#  'et',
#  'etc',
#  'euanedwardsi',
#  'euroscipy',
#  'euthanized',
#  'ev3',
#  'eval',
#  'evaluate',
#  'evaluates',
#  'evaluating',
#  'even',
#  'events',
#  'ever',
#  'eversion',
#  'every',
#  'evolved',
#  'exact',
#  'exaggerated',
#  'example',
#  'examples',
#  'exceed',
#  'excellent',
#  'except',
#  'exception',
#  'exceptions',
#  'exclusively',
#  'exec',
#  'executed',
#  'executes',
#  'executing',
#  'execution',
#  'exhibit',
#  'exhibits',
#  'exist',
#  'existing',
#  'exists',
#  'exits',
#  'exotic',
#  'expected',
#  'expects',
#  'experience',
#  'experienced',
#  'experimental',
#  'expert',
#  'explicit',
#  'exploit',
#  'explore',
#  'exponentiation',
#  'exposure',
#  'expression',
#  'expressions',
#  'extant',
#  'extended',
#  'extending',
#  'extends',
#  'extensible',
#  'extension',
#  'extensions',
#  'extensive',
#  'extensively',
#  'external',
#  'extreme',
#  'extremely',
#  'facebook',
#  'facilitate',
#  'facing',
#  'factor',
#  'factorial',
#  'fahrenheit',
#  'fail',
#  'fake',
#  'fallen',
#  'family',
#  'famous',
#  'far',
#  'farmer',
#  'fast',
#  'faster',
#  'fatalities',
#  'favored',
#  'favorite',
#  'feature',
#  'features',
#  'february',
#  'fedora',
#  ...]

# %%
bag_of_words.vocabulary_
# Out:
# {'the': 2555,
#  'reticulated': 2151,
#  'python': 2028,
#  'malayopython': 1546,
#  'reticulatus': 2153,
#  'is': 1371,
#  'snake': 2350,
#  'species': 2383,
#  'in': 1279,
#  'family': 987,
#  'pythonidae': 2031,
#  'native': 1699,
#  'to': 2592,
#  'south': 2372,
#  'and': 228,
#  'southeast': 2373,
#  'asia': 279,
#  'it': 1376,
#  'world': 2794,
#  'longest': 1518,
#  'listed': 1496,
#  'as': 278,
#  'least': 1463,
#  'concern': 600,
#  'on': 1790,
#  'iucn': 1390,
#  'red': 2081,
#  'list': 1495,
#  'because': 344,
#  'of': 1776,
#  'its': 1388,
#  'wide': 2771,
#  'distribution': 797,
#  'several': 2279,
#  'range': 2047,
#  'countries': 671,
#  'hunted': 1234,
#  'for': 1039,
#  'skin': 2336,
#  'use': 2677,
#  'traditional': 2609,
#  'medicine': 1602,
#  'sale': 2207,
#  'pet': 1886,
#  'an': 223,
#  'excellent': 936,
#  'swimmer': 2502,
#  'has': 1178,
#  'been': 346,
#  'reported': 2121,
#  'far': 989,
#  'out': 1827,
#  'at': 293,
#  'sea': 2242,
#  'colonized': 543,
#  'many': 1565,
#  'small': 2346,
#  'islands': 1374,
#  'within': 2784,
#  'among': 221,
#  'three': 2579,
#  'heaviest': 1192,
#  'snakes': 2351,
#  'like': 1487,
#  'all': 197,
#  'pythons': 2033,
#  'non': 1739,
#  'venomous': 2703,
#  'constrictor': 630,
#  'people': 1873,
#  'have': 1183,
#  'killed': 1424,
#  'two': 2635,
#  'cases': 464,
#  'eaten': 841,
#  'by': 431,
#  'taxonomy': 2529,
#  'was': 2736,
#  'first': 1019,
#  'described': 744,
#  '1801': 18,
#  'german': 1121,
#  'naturalist': 1702,
#  'johann': 1400,
#  'gottlob': 1137,
#  'theaenus': 2556,
#  'schneider': 2225,
#  'who': 2766,
#  'zoological': 2824,
#  'specimens': 2390,
#  'held': 1193,
#  'göttingen': 1164,
#  'museum': 1682,
#  'that': 2554,
#  'differed': 774,
#  'slightly': 2345,
#  'colour': 547,
#  'pattern': 1868,
#  'separate': 2265,
#  'boa': 386,
#  'reticulata': 2150,
#  'rhombeata': 2167,
#  'specific': 2384,
#  'name': 1691,
#  'latin': 1452,
#  'meaning': 1590,
#  'net': 1719,
#  'or': 1811,
#  'reference': 2086,
#  'complex': 585,
#  'color': 544,
#  'generic': 1109,
#  'proposed': 1995,
#  'french': 1070,
#  'françois': 1067,
#  'marie': 1570,
#  'daudin': 708,
#  '1803': 20,
#  'american': 217,
#  'zoologist': 2825,
#  'arnold': 268,
#  'kluge': 1429,
#  'performed': 1878,
#  'cladistics': 505,
#  'analysis': 226,
#  'morphological': 1660,
#  'characters': 487,
#  'recovered': 2080,
#  'lineage': 1490,
#  'sister': 2327,
#  'genus': 1114,
#  'hence': 1200,
#  'not': 1749,
#  'requiring': 2134,
#  'new': 1725,
#  '1993': 39,
#  '2004': 46,
#  'genetics': 1111,
#  'study': 2454,
#  'using': 2683,
#  'cytochrome': 699,
#  'dna': 803,
#  'robin': 2177,
#  'lawson': 1454,
#  'colleagues': 538,
#  'discovered': 788,
#  'australo': 306,
#  'papuan': 1843,
#  'rather': 2053,
#  'than': 2553,
#  'molurus': 1653,
#  'relatives': 2108,
#  'raymond': 2059,
#  'hoser': 1219,
#  'erected': 902,
#  'naming': 1695,
#  'after': 180,
#  'expert': 958,
#  'stefan': 2416,
#  'broghammer': 410,
#  'basis': 337,
#  'dorsal': 815,
#  'patterns': 1869,
#  'distinct': 793,
#  'from': 1077,
#  'those': 2573,
#  'dark': 703,
#  'mid': 1622,
#  'line': 1489,
#  'rear': 2072,
#  'front': 1078,
#  'head': 1187,
#  'orange': 1812,
#  'brown': 414,
#  'iris': 1368,
#  '2008': 50,
#  'lesley': 1471,
#  'rawlings': 2058,
#  'reanalysed': 2071,
#  'kruge': 1433,
#  'data': 704,
#  'combined': 554,
#  'with': 2783,
#  'genetic': 1110,
#  'material': 1577,
#  'found': 1057,
#  'clade': 504,
#  'be': 339,
#  'offshoot': 1783,
#  'well': 2748,
#  'they': 2569,
#  'adopted': 171,
#  'redefined': 2083,
#  'broghammerus': 411,
#  'however': 1227,
#  'this': 2572,
#  'numerous': 1764,
#  'other': 1823,
#  'names': 1693,
#  'same': 2212,
#  'author': 308,
#  'were': 2750,
#  'criticized': 684,
#  'authors': 309,
#  'ignoring': 1254,
#  'them': 2558,
#  'purposes': 2011,
#  'nomenclature': 1738,
#  'reynolds': 2166,
#  'subsequently': 2461,
#  'timor': 2588,
#  'calling': 440,
#  'timoriensis': 2589,
#  'since': 2324,
#  'said': 2206,
#  'junior': 1408,
#  'synonym': 2507,
#  'thus': 2582,
#  'should': 2302,
#  'recognized': 2077,
#  'international': 1350,
#  'code': 529,
#  'neither': 1716,
#  'these': 2568,
#  'reclassifications': 2076,
#  'itis': 1387,
#  'but': 430,
#  'number': 1759,
#  'subsequent': 2460,
#  'reptile': 2129,
#  'database': 705,
#  'subspecies': 2463,
#  'asiatic': 280,
#  'jampeanus': 1392,
#  'auliya': 303,
#  'et': 915,
#  'al': 191,
#  '2002': 44,
#  'kayaudi': 1413,
#  'tanahjampean': 2519,
#  'about': 139,
#  'half': 1168,
#  'length': 1468,
#  'according': 149,
#  'reaching': 2064,
#  'much': 1672,
#  'more': 1658,
#  'ft': 1080,
#  'tanahjampea': 2518,
#  'selayar': 2252,
#  'archipelago': 260,
#  'sulawesi': 2480,
#  'closely': 521,
#  'related': 2103,
#  'lesser': 1473,
#  'sundas': 2487,
#  'saputrai': 2216,
#  'selayer': 2253,
#  'occurs': 1774,
#  'island': 1373,
#  'also': 209,
#  'adjacent': 168,
#  'represents': 2125,
#  'populations': 1922,
#  'tested': 2548,
#  'does': 810,
#  'exceed': 935,
#  '13': 7,
#  'latter': 1453,
#  'are': 263,
#  'dwarf': 827,
#  'apparently': 246,
#  'population': 1921,
#  'sangihe': 2213,
#  'north': 1745,
#  'another': 236,
#  'such': 2471,
#  'which': 2761,
#  'basal': 334,
#  'plus': 1915,
#  'yet': 2813,
#  'formally': 1047,
#  'dalegibbonsi': 701,
#  'euanedwardsi': 917,
#  'haydnmacphiei': 1185,
#  'neilsonnemani': 1715,
#  'patrickcouperi': 1867,
#  'stuartbigmorei': 2451,
#  'general': 1104,
#  'acceptance': 143,
#  'description': 746,
#  'smooth': 2349,
#  'scales': 2221,
#  'arranged': 270,
#  '69': 115,
#  '79': 122,
#  'rows': 2189,
#  'midbody': 1623,
#  'deep': 726,
#  'pits': 1901,
#  'occur': 1773,
#  'four': 1059,
#  'anterior': 238,
#  'upper': 2674,
#  'labials': 1434,
#  'lower': 1524,
#  'five': 1020,
#  'six': 2329,
#  'posterior': 1931,
#  'largest': 1447,
#  'thousand': 2576,
#  'wild': 2777,
#  'southern': 2375,
#  'sumatra': 2481,
#  'studied': 2453,
#  'estimated': 913,
#  '21': 62,
#  'weight': 2746,
#  '75': 120,
#  'kg': 1423,
#  '165': 15,
#  'lb': 1457,
#  'lengths': 1469,
#  '19': 24,
#  'rare': 2049,
#  'though': 2574,
#  'guinness': 1162,
#  'book': 391,
#  'records': 2079,
#  'only': 1794,
#  'extant': 966,
#  'regularly': 2100,
#  'one': 1792,
#  'scientifically': 2229,
#  'measured': 1595,
#  'balikpapan': 327,
#  'east': 838,
#  'kalimantan': 1411,
#  'indonesia': 1305,
#  'under': 2650,
#  'anesthesia': 229,
#  '95': 129,
#  '22': 63,
#  'weighed': 2744,
#  '59': 104,
#  '130': 8,
#  'having': 1184,
#  'nearly': 1707,
#  'months': 1656,
#  'specimen': 2389,
#  'once': 1791,
#  'widely': 2772,
#  'accepted': 144,
#  'ever': 927,
#  'accurately': 150,
#  'being': 357,
#  'colossus': 546,
#  'kept': 1418,
#  'highland': 1209,
#  'park': 1851,
#  'zoo': 2823,
#  'now': 1755,
#  'pittsburgh': 1902,
#  'ppg': 1935,
#  'aquarium': 256,
#  'pennsylvania': 1872,
#  'during': 826,
#  '1950s': 28,
#  'early': 834,
#  '1960s': 30,
#  'peak': 1870,
#  'metres': 1617,
#  '28': 68,
#  'measurement': 1596,
#  'november': 1754,
#  '1956': 29,
#  'later': 1450,
#  'shown': 2306,
#  'substantially': 2464,
#  'shorter': 2300,
#  'previously': 1957,
#  'when': 2755,
#  'died': 772,
#  '14': 9,
#  'april': 255,
#  '1963': 31,
#  'body': 388,
#  'deposited': 741,
#  'carnegie': 459,
#  'natural': 1701,
#  'history': 1214,
#  'time': 2586,
#  'skeleton': 2334,
#  '20': 41,
#  '10': 1,
#  '35': 79,
#  'total': 2600,
#  'fresh': 1072,
#  'hide': 1205,
#  '23': 64,
#  '11': 2,
#  '29': 69,
#  'both': 395,
#  'measurements': 1597,
#  'significantly': 2315,
#  'what': 2753,
#  'had': 1167,
#  'tends': 2539,
#  'stretch': 2437,
#  'skinning': 2337,
#  'process': 1972,
#  'may': 1588,
#  'longer': 1517,
#  'came': 443,
#  'roughly': 2183,
#  '40': 86,
#  'previous': 1956,
#  'reports': 2122,
#  'constructed': 632,
#  'combining': 555,
#  'partial': 1854,
#  'estimations': 914,
#  'compensate': 576,
#  'kinks': 1428,
#  'completely': 583,
#  'straightening': 2428,
#  'extremely': 977,
#  'large': 1444,
#  'live': 1503,
#  'virtually': 2720,
#  'impossible': 1273,
#  'issues': 1375,
#  '2012': 54,
#  'journal': 1403,
#  'article': 274,
#  'concluded': 601,
#  'nor': 1743,
#  'maintained': 1536,
#  'captivity': 454,
#  'too': 2595,
#  'preserved': 1953,
#  'formaldehyde': 1046,
#  'then': 2560,
#  'stored': 2426,
#  'alcohol': 193,
#  'instead': 1332,
#  'prepared': 1950,
#  'disarticulated': 786,
#  'sent': 2264,
#  'laboratory': 1435,
#  'tanned': 2523,
#  'either': 854,
#  'lost': 1521,
#  'destroyed': 754,
#  'skull': 2340,
#  'selected': 2255,
#  'vertebrae': 2710,
#  'ribs': 2168,
#  'remain': 2114,
#  'collection': 541,
#  'considerable': 619,
#  'confusion': 612,
#  'exists': 950,
#  'literature': 1501,
#  'over': 1829,
#  'whether': 2760,
#  'male': 1549,
#  'female': 1005,
#  'females': 1006,
#  'tend': 2537,
#  'larger': 1446,
#  'made': 1530,
#  'none': 1740,
#  'scientist': 2230,
#  'any': 239,
#  'must': 1684,
#  'regarded': 2094,
#  'unproven': 2664,
#  'possibly': 1929,
#  'erroneous': 904,
#  'spite': 2396,
#  'years': 2812,
#  'standing': 2405,
#  'offer': 1778,
#  'financial': 1016,
#  'reward': 2164,
#  'initially': 1320,
#  '000': 0,
#  'raised': 2046,
#  '15': 10,
#  '1978': 33,
#  '50': 96,
#  '1980': 34,
#  'healthy': 1190,
#  '30': 73,
#  'long': 1516,
#  'york': 2816,
#  'society': 2356,
#  'renamed': 2117,
#  'wildlife': 2778,
#  'conservation': 617,
#  'no': 1736,
#  'attempt': 298,
#  'claim': 506,
#  'geometric': 1117,
#  'incorporates': 1286,
#  'different': 776,
#  'colours': 549,
#  'back': 319,
#  'typically': 2639,
#  'series': 2270,
#  'irregular': 1370,
#  'diamond': 768,
#  'shapes': 2286,
#  'flanked': 1022,
#  'smaller': 2347,
#  'markings': 1572,
#  'light': 1485,
#  'centers': 474,
#  'geographic': 1115,
#  'variation': 2697,
#  'size': 2331,
#  'commonly': 565,
#  'exhibits': 947,
#  'seem': 2249,
#  'garish': 1099,
#  'shadowy': 2283,
#  'jungle': 1407,
#  'environment': 894,
#  'amid': 218,
#  'fallen': 986,
#  'leaves': 1465,
#  'debris': 715,
#  'allows': 204,
#  'disappear': 785,
#  'called': 439,
#  'disruptive': 792,
#  'colouration': 548,
#  'protects': 1998,
#  'predators': 1941,
#  'helps': 1197,
#  'catch': 465,
#  'their': 2557,
#  'prey': 1958,
#  'huge': 1229,
#  'attractive': 301,
#  'favorite': 995,
#  'exhibit': 946,
#  'individuals': 1303,
#  'claimed': 507,
#  'above': 140,
#  'due': 824,
#  'immense': 1262,
#  'strength': 2434,
#  'aggressive': 183,
#  'disposition': 791,
#  'mobility': 1639,
#  'relative': 2106,
#  'very': 2711,
#  'difficult': 779,
#  'get': 1122,
#  'exact': 931,
#  'living': 1505,
#  'weights': 2747,
#  'rarely': 2050,
#  'indicative': 1300,
#  'captive': 453,
#  'often': 1785,
#  'obese': 1766,
#  'claims': 508,
#  'zoos': 2826,
#  'animal': 231,
#  'parks': 1852,
#  'sometimes': 2364,
#  'exaggerated': 932,
#  '85': 126,
#  '48': 94,
#  'proven': 2000,
#  'reason': 2073,
#  'scientists': 2231,
#  'do': 804,
#  'accept': 142,
#  'validity': 2689,
#  'unless': 2659,
#  'dead': 711,
#  'anesthetized': 230,
#  'scientific': 2228,
#  'research': 2136,
#  'kansas': 1412,
#  'city': 502,
#  'missouri': 1631,
#  'named': 1692,
#  'medusa': 1603,
#  'considered': 620,
#  '2011': 53,
#  'measure': 1594,
#  '67': 113,
#  '25': 66,
#  'weigh': 2743,
#  '158': 12,
#  '350': 80,
#  'forms': 1054,
#  'some': 2361,
#  'northwest': 1746,
#  'australia': 304,
#  'selectively': 2256,
#  'bred': 402,
#  'resulting': 2147,
#  'animals': 232,
#  'referred': 2088,
#  'super': 2488,
#  'dwarfs': 828,
#  'adult': 173,
#  'between': 369,
#  '82': 125,
#  'habitat': 1165,
#  'nicobar': 1731,
#  'india': 1297,
#  'bangladesh': 330,
#  'burma': 425,
#  'thailand': 2552,
#  'laos': 1442,
#  'cambodia': 442,
#  'vietnam': 2717,
#  'malaysia': 1547,
#  'singapore': 2325,
#  'through': 2580,
#  'indo': 1304,
#  'australian': 305,
#  'mentawai': 1607,
#  'natuna': 1700,
#  'borneo': 393,
#  'java': 1394,
#  'lombok': 1515,
#  'sumbawa': 2483,
#  'sumba': 2482,
#  'flores': 1029,
#  'maluku': 1552,
#  'tanimbar': 2520,
#  'philippines': 1891,
#  'basilan': 336,
#  'bohol': 389,
#  'cebu': 471,
#  'leyte': 1477,
#  'luzon': 1527,
#  'mindanao': 1626,
#  'mindoro': 1627,
#  'negros': 1714,
#  'palawan': 1838,
#  'panay': 1841,
#  'polillo': 1918,
#  'samar': 2211,
#  'tawi': 2527,
#  'original': 1820,
#  'include': 1281,
#  'type': 2636,
#  'locality': 1508,
#  'restricted': 2145,
#  'brongersma': 412,
#  '1972': 32,
#  'integrated': 1338,
#  'taxonomic': 2528,
#  'information': 1315,
#  'system': 2511,
#  'can': 445,
#  'vary': 2701,
#  'great': 1144,
#  'deal': 712,
#  'geographical': 1116,
#  'location': 1509,
#  'good': 1135,
#  'key': 1420,
#  'establishing': 912,
#  'each': 831,
#  'lives': 1504,
#  'rain': 2043,
#  'forests': 1043,
#  'woodlands': 2789,
#  'nearby': 1705,
#  'grasslands': 1142,
#  'associated': 291,
#  'rivers': 2174,
#  'areas': 265,
#  'streams': 2433,
#  'lakes': 1437,
#  'even': 925,
#  'consequently': 616,
#  '20th': 61,
#  'century': 477,
#  'common': 564,
#  'busy': 429,
#  'parts': 1858,
#  'bangkok': 329,
#  'eating': 842,
#  'domestic': 814,
#  'behaviour': 354,
#  'ecology': 844,
#  'diet': 773,
#  'ambush': 216,
#  'hunter': 1235,
#  'usually': 2685,
#  'waiting': 2731,
#  'until': 2669,
#  'wanders': 2733,
#  'strike': 2439,
#  'before': 347,
#  'seizing': 2251,
#  'coils': 537,
#  'killing': 1425,
#  'constriction': 629,
#  'includes': 1283,
#  'mammals': 1554,
#  'occasionally': 1772,
#  'birds': 376,
#  'up': 2671,
#  'eat': 840,
#  'mainly': 1534,
#  'rodents': 2178,
#  'rats': 2056,
#  'whereas': 2758,
#  'switch': 2503,
#  'indian': 1298,
#  'civet': 503,
#  'binturong': 373,
#  'primates': 1960,
#  'pigs': 1898,
#  'weighing': 2745,
#  '60': 108,
#  'rule': 2194,
#  'seems': 2250,
#  'able': 138,
#  'swallow': 2498,
#  'quarter': 2037,
#  'own': 1831,
#  'near': 1704,
#  'human': 1230,
#  'habitation': 1166,
#  'known': 1432,
#  'snatch': 2352,
#  'stray': 2432,
#  'chickens': 493,
#  'cats': 466,
#  'dogs': 812,
#  'occasion': 1771,
#  'documented': 807,
#  'items': 1379,
#  'starved': 2407,
#  'sun': 2486,
#  'bear': 340,
#  '51': 98,
#  'took': 2596,
#  'weeks': 2742,
#  'digest': 781,
#  'case': 463,
#  'foraging': 1040,
#  'entering': 889,
#  'forest': 1042,
#  'hut': 1240,
#  'taking': 2517,
#  'child': 495,
#  'reproduction': 2126,
#  'oviparous': 1830,
#  'lay': 1455,
#  '80': 123,
#  'eggs': 851,
#  'per': 1876,
#  'clutch': 523,
#  'optimum': 1809,
#  'incubation': 1293,
#  'temperature': 2534,
#  '31': 75,
#  '32': 76,
#  '88': 127,
#  '90': 128,
#  'take': 2515,
#  'average': 314,
#  'days': 710,
#  'hatch': 1181,
#  'hatchlings': 1182,
#  '61': 111,
#  'cm': 525,
#  'danger': 702,
#  'humans': 1231,
#  'few': 1009,
#  'attacks': 297,
#  'responsible': 2144,
#  'fatalities': 993,
#  'considering': 621,
#  'maximum': 1587,
#  'full': 1081,
#  'grown': 1155,
#  'open': 1796,
#  'jaws': 1397,
#  'enough': 885,
#  'width': 2774,
#  'shoulders': 2304,
#  'homo': 1218,
#  'sapiens': 2215,
#  'pose': 1926,
#  'problem': 1968,
#  'sufficient': 2474,
#  'consumption': 634,
#  'latest': 1451,
#  'examples': 934,
#  'authenticated': 307,
#  'salibabu': 2208,
#  'year': 2810,
#  'old': 1786,
#  'boy': 398,
#  'supposedly': 2494,
#  '17': 16,
#  'incident': 1280,
#  'involved': 1364,
#  'woman': 2787,
#  'reputedly': 2133,
#  'details': 755,
#  '1910s': 25,
#  '1927': 26,
#  'jeweller': 1398,
#  'went': 2749,
#  'hunting': 1236,
#  'his': 1213,
#  'friends': 1075,
#  'he': 1186,
#  'sought': 2367,
#  'shelter': 2295,
#  'rainstorm': 2044,
#  'tree': 2617,
#  'swallowed': 2499,
#  'feet': 1003,
#  'contrary': 649,
#  'normal': 1744,
#  'perhaps': 1879,
#  'easiest': 836,
#  'way': 2737,
#  'actually': 157,
#  '1932': 27,
#  'frank': 1066,
#  'buck': 416,
#  'wrote': 2804,
#  'teenaged': 2533,
#  'escaped': 907,
#  'shape': 2285,
#  'inside': 1325,
#  'turned': 2631,
#  'son': 2365,
#  'owner': 1832,
#  'group': 1152,
#  'aeta': 177,
#  'negritos': 1713,
#  'deaths': 714,
#  'period': 1880,
#  'infected': 1308,
#  'bite': 378,
#  'september': 2266,
#  '1995': 40,
#  'rubber': 2192,
#  'tapper': 2524,
#  'malaysian': 1548,
#  'state': 2408,
#  'johor': 1402,
#  'victim': 2714,
#  'caught': 467,
#  'unaware': 2648,
#  'squeezed': 2401,
#  'death': 713,
#  'coiled': 535,
#  'around': 269,
#  'lifeless': 1484,
#  'gripped': 1148,
#  'stumbled': 2455,
#  'upon': 2673,
#  'brother': 413,
#  'measuring': 1598,
#  '300': 74,
#  'soon': 2366,
#  'arriving': 273,
#  'police': 1917,
#  'shot': 2301,
#  'times': 2587,
#  'october': 1775,
#  'appeared': 248,
#  'foot': 1038,
#  'apparent': 245,
#  'cause': 468,
#  'asphyxiation': 283,
#  'bedroom': 345,
#  'agitated': 184,
#  'january': 1393,
#  '2009': 51,
#  'wrapped': 2798,
#  '18': 17,
#  'turning': 2632,
#  'blue': 385,
#  'mother': 1664,
#  'petsitting': 1889,
#  'behalf': 351,
#  'friend': 1073,
#  'rescued': 2135,
#  'toddler': 2593,
#  'gashing': 1100,
#  'knife': 1430,
#  'euthanized': 919,
#  'wounds': 2797,
#  'december': 718,
#  '2013': 55,
#  'security': 2247,
#  'guard': 1158,
#  'strangled': 2430,
#  'while': 2762,
#  'trying': 2624,
#  'capture': 455,
#  'bali': 326,
#  'hyatt': 1241,
#  'luxury': 1526,
#  'hotel': 1223,
#  'resort': 2138,
#  'happened': 1176,
#  'am': 214,
#  'crossing': 686,
#  'road': 2175,
#  'offered': 1779,
#  'help': 1195,
#  'spotted': 2398,
#  'sanur': 2214,
#  'area': 264,
#  'into': 1358,
#  'bushes': 428,
#  'march': 1568,
#  '2017': 57,
#  'akbar': 190,
#  'salubiro': 2210,
#  'farmer': 990,
#  'central': 475,
#  'mamuju': 1555,
#  'regency': 2096,
#  'west': 2752,
#  'stomach': 2423,
#  'declared': 724,
#  'missing': 1630,
#  'palm': 1840,
#  'plantation': 1909,
#  'searching': 2244,
#  'him': 1212,
#  'next': 1729,
#  'day': 709,
#  'bulge': 424,
#  'whole': 2767,
#  'fully': 1082,
#  'confirmed': 609,
#  'person': 1884,
#  'retrieving': 2156,
#  'pictures': 1897,
#  'videos': 2716,
#  'taken': 2516,
#  'witnesses': 2786,
#  'june': 1406,
#  '2018': 58,
#  '54': 101,
#  'indonesian': 1306,
#  'muna': 1681,
#  'night': 1733,
#  'working': 2792,
#  'her': 1201,
#  'garden': 1098,
#  'search': 2243,
#  'party': 1859,
#  'organized': 1818,
#  'belongings': 359,
#  'abandoned': 133,
#  'carried': 461,
#  'town': 2605,
#  'where': 2757,
#  'cut': 694,
#  'revealing': 2159,
#  'intact': 1334,
#  'video': 2715,
#  'gutted': 1163,
#  'posted': 1930,
#  'online': 1793,
#  'increased': 1288,
#  'popularity': 1920,
#  'trade': 2607,
#  'largely': 1445,
#  'efforts': 850,
#  'breeding': 405,
#  'mutations': 1686,
#  'albino': 192,
#  'tiger': 2584,
#  'strains': 2429,
#  'make': 1542,
#  'keepers': 1416,
#  'experience': 955,
#  'constrictors': 631,
#  'ensure': 887,
#  'safety': 2203,
#  'keeper': 1415,
#  'although': 212,
#  'interactivity': 1344,
#  'beauty': 342,
#  ...}

# %%
counts_animal = bag_of_words.transform(animal_sents)
counts_program = bag_of_words.transform(program_sents)

ind_programming = bag_of_words.vocabulary_['programming']

print(counts_animal.sum(axis=0)[0, ind_programming])
print(counts_program.sum(axis=0)[0, ind_programming])
# Out:
# 0
# 30

# %%
from sklearn.feature_extraction.text import HashingVectorizer

hashing_bag_of_words = HashingVectorizer(norm=None)
hashing_bag_of_words.fit(documents)
hashing_bag_of_words.transform(documents)
# Out:
# <856x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9166 stored elements in Compressed Sparse Row format>

# %%
import time 

t_0 = time.time()
CountVectorizer().fit_transform(documents)
time_elapse = time.time()-t_0
print('count vectorizer time {}'.format(time_elapse))

t_0 = time.time()
HashingVectorizer(norm=None).fit_transform(documents)
time_elapse =time.time() - t_0
print('hash vectorizer time {}'.format(time_elapse))
# Out:
# count vectorizer time 0.12081050872802734
# hash vectorizer time 0.051918745040893555

# %%
#word_counts = counts_animal + counts_program
from sklearn.feature_extraction.text import TfidfTransformer
tfidf = TfidfTransformer()
tfidf_weights = tfidf.fit_transform(word_counts)
print(tfidf_weights)
# Out:
#   (0, 2592)	0.11586225203909407
#   (0, 2555)	0.1981108895875376
#   (0, 2383)	0.26885735503913727
#   (0, 2373)	0.31533309122087
#   (0, 2372)	0.3017015278652415
#   (0, 2350)	0.20467339368465554
#   (0, 2153)	0.27518462327317567
#   (0, 2151)	0.1975879632720815
#   (0, 2031)	0.33454570069134576
#   (0, 2028)	0.10482194760429729
#   (0, 1699)	0.27518462327317567
#   (0, 1546)	0.2911280658791825
#   (0, 1371)	0.1306013411949939
#   (0, 1279)	0.11704988626970254
#   (0, 987)	0.33454570069134576
#   (0, 279)	0.3017015278652415
#   (0, 228)	0.10408443660292804
#   (1, 2794)	0.2632706988439691
#   (1, 2771)	0.2564633278074306
#   (1, 2555)	0.18463305621576495
#   (1, 2350)	0.19074910158006575
#   (1, 2081)	0.27132210988183536
#   (1, 1790)	0.1705309634271401
#   (1, 1776)	0.11091752516850925
#   (1, 1518)	0.27132210988183536
#   :	:
#   (847, 65)	0.5460962275187211
#   (848, 2485)	0.6409874803477728
#   (848, 1571)	0.5577995622744075
#   (848, 51)	0.5272520254715888
#   (849, 2028)	0.3937897826095356
#   (849, 1986)	0.8071986741004371
#   (849, 1279)	0.439727083135473
#   (850, 845)	0.6451590335822629
#   (850, 71)	0.7640483108987289
#   (851, 2751)	0.5773502691896258
#   (851, 1979)	0.5773502691896258
#   (851, 162)	0.5773502691896258
#   (852, 1372)	0.44919807467287876
#   (852, 130)	0.44919807467287876
#   (852, 114)	0.5460962275187211
#   (852, 77)	0.5460962275187211
#   (854, 1492)	0.7196039967296557
#   (854, 975)	0.6943846829320945
#   (855, 2741)	0.5008266240754431
#   (855, 2028)	0.15692212465796376
#   (855, 1986)	0.3216623095742673
#   (855, 1781)	0.451657747706518
#   (855, 1440)	0.2883222759025425
#   (855, 689)	0.5008266240754431
#   (855, 293)	0.2883222759025425

# %%
top_tfidf_score = tfidf.idf_.argsort()[:-20:-1]
ind_feature = bag_of_words.get_feature_names()

for ind in top_tfidf_score:
    print(tfidf.idf_[ind],ind_feature[ind])
# Out:
# 7.060290738037835 zope
# 7.060290738037835 handle
# 7.060290738037835 gripped
# 7.060290738037835 gripping
# 7.060290738037835 groovy
# 7.060290738037835 grow
# 7.060290738037835 growing
# 7.060290738037835 grumpy
# 7.060290738037835 guard
# 7.060290738037835 guide
# 7.060290738037835 guinea
# 7.060290738037835 gutted
# 7.060290738037835 göttingen
# 7.060290738037835 habitation
# 7.060290738037835 hall
# 7.060290738037835 hamilton
# 7.060290738037835 handled
# 7.060290738037835 functools
# 7.060290738037835 handling

# %%
from spacy.lang.en import STOP_WORDS
print(type(STOP_WORDS))
STOP_WORDS_python = STOP_WORDS.union({'python'})
STOP_WORDS_python
# Out:
# <class 'set'>
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'python',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
print([word.lemma_ for word in nlp('run runs ran running runs')])
print([word.lemma_ for word in nlp('dance dancing dances')])
print([word.lemma_ for word in nlp('buy buys bought buying')])
print([word.lemma_ for word in nlp('sea saw see seen seeing')])
# Out:
# ['run', 'run', 'run', 'run', 'run']
# ['dance', 'dance', 'dance']
# ['buy', 'buys', 'buy', 'buying']
# ['sea', 'see', 'see', 'see', 'see']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def lemmatizer(text):
    return [word.lemma_ for word in nlp(text)]
    
stop_word = ''.join(STOP_WORDS)
lemma_words = set(word.lemma_ for word in nlp(stop_word))
tfidf_vector = TfidfVectorizer(max_features=100,
                               stop_words = STOP_WORDS.union({'python'}),
                               tokenizer=lemmatizer)
tfidf_vector.fit(documents)
print(tfidf_vector.get_feature_names())
# Out:
# C:\Users\GORDON OUMA GOGAH\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'", '-PRON-', 'd', 'm', 'regard', 'use', 've'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# ['\n', '\n\n', '\n\n\n', ' ', '"', "'", '(', ')', ',', '-', '-PRON-', '.', '1', '2', '3', ':', ';', '<', '=', 'allow', 'b', 'ball', 'block', 'body', 'breed', 'c', 'captivity', 'class', 'code', 'common', 'cpython', 'describe', 'design', 'development', 'division', 'e.g.', 'eat', 'egg', 'example', 'expression', 'feature', 'female', 'find', 'ft', 'function', 'generator', 'human', 'implementation', 'include', 'integer', 'island', 'java', 'kill', 'language', 'large', 'later', 'length', 'library', 'like', 'list', 'long', 'm', 'm.', 'male', 'measure', 'method', 'module', 'new', 'number', 'object', 'old', 'operator', 'pattern', 'pet', 'program', 'programming', 'propose', 'provide', 'r.', 'range', 'reference', 'release', 'report', 'reticulate', 'small', 'snake', 'standard', 'statement', 'string', 'support', 'syntax', 'system', 'time', 'type', 'use', 'value', 'variable', 'version', 'write', 'year']

# %%
bgrams_counter = CountVectorizer(max_features=20,ngram_range=(2,2),stop_words=STOP_WORDS.union({"python"}))
bgrams_counter.fit(documents)
bgrams_counter.get_feature_names()
# Out:
# C:\Users\GORDON OUMA GOGAH\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# ['23 ft',
#  'ball pythons',
#  'block code',
#  'floating point',
#  'ft length',
#  'guido van',
#  'isbn 978',
#  'list comprehensions',
#  'new features',
#  'object oriented',
#  'oriented programming',
#  'programming language',
#  'programming languages',
#  'reference implementation',
#  'reticulated pythons',
#  'scripting language',
#  'spam eggs',
#  'standard library',
#  'van rossum',
#  'year old']

# %%
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

documents = animal_sents + program_sents
label = ['animal']*len(animal_sents) + ['program']*len(program_sents)

stop_words_str = ''.join(STOP_WORDS)
set_lemma_word = set(word.lemma_ for word in nlp(stop_words_str))

tfidf_lemma = TfidfVectorizer(stop_words = set_lemma_word,tokenizer=lemmatizer, ngram_range=(1, 2))
pipe = Pipeline([('vectorizer',tfidf_lemma),('classifier',MultinomialNB())])
pipe.fit(documents, label)
print('Training accuracy: {}'.format(pipe.score(documents,label)))
# Out:
# Training accuracy: 0.9170560747663551

# %%
test_docs = ["My Python program is only 100 bytes long.",
             "A python's bite is not venomous but still hurts.",
             "I can't find the error in the python code.",
             "Where is my pet python; I can't find her!",
             "I use for and while loops when writing Python.",
             "The python will loop and wrap itself onto me.",
             "I use snake case for naming my variables.",
             "My python has grown to over 10 ft long!",
             "I use virtual environments to manage package versions.",
             "Pythons are the largest snakes in the environment."]
class_label = ['animal','language']
y_prob = pipe.predict_proba(test_docs)
predicted_indices = (y_prob[:, 1] > 0.5).astype(int)

for i, index in enumerate (predicted_indices):
    print(test_docs[i], '--> {} at {:g}%'.format(class_label[index], 100 * y_prob[i,index]))
# Out:
# My Python program is only 100 bytes long. --> language at 68.796%
# A python's bite is not venomous but still hurts. --> language at 64.8024%
# I can't find the error in the python code. --> language at 74.2181%
# Where is my pet python; I can't find her! --> language at 62.5303%
# I use for and while loops when writing Python. --> language at 86.4272%
# The python will loop and wrap itself onto me. --> language at 70.8047%
# I use snake case for naming my variables. --> language at 71.6721%
# My python has grown to over 10 ft long! --> language at 51.7361%
# I use virtual environments to manage package versions. --> language at 84.5939%
# Pythons are the largest snakes in the environment. --> animal at 63.4977%

# %%
lemmatizer('Dogs are running quickly.')
# Out:
# ['dog', 'be', 'run', 'quickly', '.']

# %%
TfidfVectorizer?

# %%
,
